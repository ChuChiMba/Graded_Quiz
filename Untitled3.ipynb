# %% [markdown]
# <a href="https://colab.research.google.com/github/ChuChiMba/Graded_Quiz/blob/First-Assessment/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files

# %%
df = pd.read_csv("/content/FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding = "latin-1")
print(df)
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
df.groupby('Element').count()
# Out:
#                                         Area Code  Area  Item Code  Item  \
# Element
# Domestic supply quantity                     5295  5295       5295  5295
# Export Quantity                              4403  4403       4403  4403
# Fat supply quantity (g/capita/day)           5023  5023       5023  5023
# Feed                                         1319  1319       1319  1319
# Food                                         4941  4941       4941  4941
# Food supply (kcal/capita/day)                5014  5014       5014  5014
# Food supply quantity (kg/capita/yr)          4905  4905       4905  4905
# Import Quantity                              5139  5139       5139  5139
# Losses                                       2009  2009       2009  2009
# Other uses (non-food)                        1732  1732       1732  1732
# Processing                                   2010  2010       2010  2010
# Production                                   3881  3881       3881  3881
# ...

# %%
df.groupby('Item').sum()
# Out:
# <ipython-input-60-a36e0a1607b9>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Item').sum()
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# ...

# %%
df.groupby('Element').sum()
# Out:
# <ipython-input-61-ba0985c2a5c7>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Element').sum()
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# ...

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df.Area.duplicated()
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 60938     True
# 60939     True
# 60940     True
# 60941     True
# 60942     True
# Name: Area, Length: 60943, dtype: bool

# %%
df_new = df.iloc[:, [1,10]]

# %%
df.groupby('Area').count()
# Out:
#                              Area Code  Item Code  Item  Element Code  \
# Area
# Algeria                           1313       1313  1313          1313
# Angola                            1424       1424  1424          1424
# Benin                             1285       1285  1285          1285
# Botswana                          1378       1378  1378          1378
# Burkina Faso                      1409       1409  1409          1409
# Cabo Verde                        1260       1260  1260          1260
# Cameroon                          1460       1460  1460          1460
# Central African Republic          1344       1344  1344          1344
# Chad                              1343       1343  1343          1343
# Comoros                             45         45    45            45
# Congo                             1413       1413  1413          1413
# Côte d'Ivoire                     1467       1467  1467          1467
# ...

# %%
df.corr(method='kendall')
# Out:
# <ipython-input-89-447f87d54f08>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='kendall')
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.003807      0.000077  0.016511  0.017399
# Item Code     -0.003807   1.000000     -0.015003  0.092185  0.093783
# Element Code   0.000077  -0.015003      1.000000 -0.002848 -0.005358
# Y2014          0.016511   0.092185     -0.002848  1.000000  0.909291
# Y2015          0.017399   0.093783     -0.005358  0.909291  1.000000
# Y2016          0.014528   0.094614     -0.000947  0.889675  0.908289
# Y2017          0.014069   0.094090      0.001603  0.872313  0.888758
# Y2018          0.015546   0.093288     -0.002801  0.861810  0.875977
#
#                  Y2016     Y2017     Y2018
# ...
